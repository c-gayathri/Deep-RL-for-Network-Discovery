# %%
import pickle
import networkx as nx

# %%
G = nx.read_gpickle('sbm_400.gpickle')

# %%
open(file, 'r') as f: my_list = pickle.load(f)

# %%
G.to_pickle('sbm_400_4.gpickle')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e3e7e02048f1> in <module>
# ----> 1 G.to_pickle('sbm_400_4.gpickle')
#
# AttributeError: 'Graph' object has no attribute 'to_pickle'

# %%
nx.write_gpickle(G, 'sbm_400_4.gpickle', 4)
